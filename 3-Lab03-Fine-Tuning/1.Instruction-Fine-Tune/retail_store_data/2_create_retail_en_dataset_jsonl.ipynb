# %% [markdown]
# # Retail Store JSONL FILE 데이터 셋 생성
# 아래의 Git에서 인공적으로 생성된 데이터 세트를 사용 함.
#
# 생성된 데이터 세트를 retail_stores_items.csv 저장 했습니다.
# - [원본 Retail Demo Store Git Repo](https://github.com/aws-samples/retail-demo-store)

# %% [markdown]
# # 0. 선수 사항
# - 이 노트북은 "Amazon Translate" 서비스를 이용합니다. 그래서 이 노트북을 실행하는 Role 에 "TranslateFullAccess" Permission 이 추가 되어져야 합니다.

# %% [markdown]
# # 1. 데이터 로딩

# %%
import boto3

translate_client = boto3.client(service_name='translate', region_name='us-east-1', use_ssl=True)

# %%
import pandas as pd

raw = pd.read_csv("retail_stores_items.csv")
print(raw.columns)
raw.head(3)
# Out:
# Index(['id', 'url', 'sk', 'name', 'category', 'style', 'description',
#        'aliases', 'price', 'image', 'gender_affinity', 'current_stock',
#        'featured'],
#       dtype='object')
#                                      id  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1
#
#                                                  url  sk               name  \
# 0  http://d32da96qlo1y4g.cloudfront.net/#/product... NaN  Sans Pareil Scarf
# 1  http://d32da96qlo1y4g.cloudfront.net/#/product... NaN         Chef Knife
# 2  http://d32da96qlo1y4g.cloudfront.net/#/product... NaN   Gainsboro Jacket
#
#      category    style                                        description  \
# 0     apparel    scarf                        Sans pareil scarf for women
# 1  housewares  kitchen                       A must-have for your kitchen
# 2     apparel   jacket  This gainsboro jacket for women is perfect for...
#
#   aliases   price                                              image  \
# 0     NaN  124.99  http://d32da96qlo1y4g.cloudfront.net/images/ap...
# 1     NaN   57.99  http://d32da96qlo1y4g.cloudfront.net/images/ho...
# 2     NaN  133.99  http://d32da96qlo1y4g.cloudfront.net/images/ap...
#
#   gender_affinity  current_stock featured
# 0               F             12      NaN
# 1             NaN              9      NaN
# 2               F             13      NaN

# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 주요 컬럼만 유지하고 삭제

# %%
def preprocess_data(raw):
    def create_sinlge_category(s):
        category = s[2]
        style = s[3]        
        single_category = f"{category}|{style}"
        # print(f"{category}|{style}")
        
        return single_category
    
    df = raw.copy()
    df = df.drop(columns=['url','sk','aliases', 'price', 'image', 'gender_affinity', 'current_stock', 'featured'])
    
    df['single_category'] = df.apply(create_sinlge_category, axis=1)
    df = df.drop(columns=['style','category'])
    # df = df.dropna(axis=0, how='any')
    # df = df.reset_index(drop=True)
    return df

df_en = preprocess_data(raw)
df_en.head(3)
# Out:
# /tmp/ipykernel_14069/2761729219.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   category = s[2]
# /tmp/ipykernel_14069/2761729219.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   style = s[3]
#                                      id               name  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651  Sans Pareil Scarf
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d         Chef Knife
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1   Gainsboro Jacket
#
#                                          description     single_category
# 0                        Sans pareil scarf for women       apparel|scarf
# 1                       A must-have for your kitchen  housewares|kitchen
# 2  This gainsboro jacket for women is perfect for...      apparel|jacket

# %% [markdown]
# ## description, single_category 를 한국어로 번역

# %%
# %%time

import pandas as pd

# df = pd.read_csv("amazon_faq_en.csv")
# print(df.columns)

def translate_df(df, target_col, new_col, length):
    
    def translate(df, length):
        text = df[target_col]
        result = translate_client.translate_text(Text=text, 
                SourceLanguageCode="en", TargetLanguageCode="ko")
        result = result['TranslatedText']
        result = result[0:length]
        return result
    df[new_col] = df.apply(translate, length=length, axis=1)
    
    return df

# token_length = 200 # 200 --> Error
token_length = 1200

# df_ko = translate_df(df_en, target_col='description', new_col='description_ko', length = token_length)
# df_ko = translate_df(df_en, target_col='single_category', new_col='single_category_ko', length = token_length)
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 8.34 µs

# %%
df_en
# Out:
#                                         id                      name  \
# 0     e1669081-8ffc-4dec-97a6-e9176d7f6651         Sans Pareil Scarf
# 1     cfafd627-7d6b-43a5-be05-4c7937be417d                Chef Knife
# 2     6e6ad102-7510-4a02-b8ce-5a0cd6f431d1          Gainsboro Jacket
# 3     49b89871-5fe7-4898-b99d-953e15fb42b2  High Definition Speakers
# 4     5cb18925-3a3c-4867-8f1c-46efd7eba067            Spiffy Sandals
# ...                                    ...                       ...
# 2460  36cfd856-dd30-46a9-8654-1f1de77e674a             Easter Wreath
# 2461  1ea9439f-dff5-41cf-aac3-718a6b4e7af6            White Sneakers
# 2462  ccdf737c-c4fd-4c78-abd2-d5ef0428ef20                Wine Glass
# 2463  12f93a36-e282-4445-92ae-356eb6a560fd         Roses Arrangement
# 2464  23e77743-ff28-400a-811f-e08d3cab5e45           Ultrachic Scarf
#
#                                             description      single_category
# 0                           Sans pareil scarf for women        apparel|scarf
# 1                          A must-have for your kitchen   housewares|kitchen
# 2     This gainsboro jacket for women is perfect for...       apparel|jacket
# 3     High definition speakers to fill the house wit...  electronics|speaker
# 4     This spiffy pair of sandals for woman is perfe...     footwear|sandals
# ...                                                 ...                  ...
# 2460  Easter wreath grown sustainably on our organic...        floral|wreath
# 2461       An all-around voguish pair of white sneakers     footwear|sneaker
# 2462                            Ideal for every kitchen   housewares|kitchen
# 2463  Roses arrangement grown sustainably on our org...   floral|arrangement
# 2464       Ultrachic scarf for women for every occasion        apparel|scarf
#
# [2465 rows x 4 columns]

# %% [markdown]
# ## single_category_ko 가 size_limit (예: 30) 이상 있는 것만 유지

# %%
pd.set_option('display.max_rows', 100)

def filter_dataset(df, size_limit=10):
    '''
    size_limit 이상인 카테고리만을 추출 함.
    '''
    print("Original shape: ", df.shape)    
    stat = df.groupby('single_category').count()
    stat = pd.DataFrame(stat)
    # print("stat columns: ", stat.columns)    
    # print("single_category: ", stat.index)    

    stat = stat[stat.id > size_limit]
    stat = stat[stat.id > size_limit]
    
    stat = df[df.single_category.isin(stat.index)]
    print("new_df shape: ", stat.shape)    
    
    return stat

size_limit = 30
filter_df = filter_dataset(df_en, size_limit = size_limit)
filter_df.head()
# Out:
# Original shape:  (2465, 4)
# new_df shape:  (1871, 4)
#                                      id                  name  \
# 0  e1669081-8ffc-4dec-97a6-e9176d7f6651     Sans Pareil Scarf
# 1  cfafd627-7d6b-43a5-be05-4c7937be417d            Chef Knife
# 2  6e6ad102-7510-4a02-b8ce-5a0cd6f431d1      Gainsboro Jacket
# 4  5cb18925-3a3c-4867-8f1c-46efd7eba067        Spiffy Sandals
# 5  91cc9fa1-d8e9-46ae-9c8d-86264de2c6cc  Stylish Ceramic Bowl
#
#                                          description     single_category
# 0                        Sans pareil scarf for women       apparel|scarf
# 1                       A must-have for your kitchen  housewares|kitchen
# 2  This gainsboro jacket for women is perfect for...      apparel|jacket
# 4  This spiffy pair of sandals for woman is perfe...    footwear|sandals
# 5           This stylish ceramic bowl is a must-have    housewares|bowls

# %% [markdown]
# # 3. Train, Val 데이터 셋으로 층화 분리

# %%
from sklearn.model_selection import train_test_split

import numpy as np

def split_stratify_dataset(raw, test_size=0.2):
    X, y = raw.description, raw.single_category
    # 층화 데이터셋 분리
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, stratify=y, random_state=42)

    # 각 데이터셋의 클래스 비율 확인
    unique_train, counts_train = np.unique(y_train, return_counts=True)
    unique_test, counts_test = np.unique(y_test, return_counts=True)

    print("Train set class distribution:")
    print(dict(zip(unique_train, counts_train)))

    print("\nTest set class distribution:")
    print(dict(zip(unique_test, counts_test)))
    
    train_df = pd.DataFrame({'prompt': X_train, 'completion': y_train}).reset_index(drop=True)
    test_df = pd.DataFrame({'prompt': X_test, 'completion': y_test}).reset_index(drop=True)    
    
    return train_df, test_df

train_df, val_df = split_stratify_dataset(filter_df, test_size=0.1)
# Out:
# Train set class distribution:
# {'accessories|backpack': 43, 'accessories|belt': 34, 'accessories|glasses': 53, 'accessories|handbag': 34, 'apparel|jacket': 73, 'apparel|scarf': 48, 'apparel|shirt': 60, 'beauty|grooming': 37, 'electronics|camera': 32, 'floral|arrangement': 32, 'floral|plant': 38, 'footwear|formal': 71, 'footwear|sandals': 28, 'footwear|sneaker': 43, 'furniture|chairs': 65, 'furniture|dressers': 29, 'furniture|sofas': 44, 'furniture|tables': 83, 'groceries|bakery': 49, 'groceries|meat': 28, 'groceries|vegetables': 37, 'homedecor|cushion': 41, 'homedecor|decorative': 58, 'homedecor|lighting': 48, 'housewares|bowls': 49, 'housewares|kitchen': 144, 'instruments|keys': 30, 'instruments|percussion': 36, 'instruments|strings': 55, 'jewelry|bracelet': 33, 'outdoors|fishing': 33, 'seasonal|christmas': 83, 'seasonal|easter': 38, 'seasonal|halloween': 41, 'seasonal|valentine': 33}
#
# Test set class distribution:
# {'accessories|backpack': 5, 'accessories|belt': 4, 'accessories|glasses': 6, 'accessories|handbag': 4, 'apparel|jacket': 8, 'apparel|scarf': 5, 'apparel|shirt': 7, 'beauty|grooming': 4, 'electronics|camera': 4, 'floral|arrangement': 4, 'floral|plant': 4, 'footwear|formal': 8, 'footwear|sandals': 3, 'footwear|sneaker': 5, 'furniture|chairs': 7, 'furniture|dressers': 3, 'furniture|sofas': 5, 'furniture|tables': 9, 'groceries|bakery': 5, 'groceries|meat': 3, 'groceries|vegetables': 4, 'homedecor|cushion': 5, 'homedecor|decorative': 7, 'homedecor|lighting': 5, 'housewares|bowls': 5, 'housewares|kitchen': 16, 'instruments|keys': 3, 'instruments|percussion': 4, 'instruments|strings': 6, 'jewelry|bracelet': 4, 'outdoors|fishing': 4, 'seasonal|christmas': 9, 'seasonal|easter': 4, 'seasonal|halloween': 5, 'seasonal|valentine': 4}

# %%
train_df.head(5)
# Out:
#                                               prompt          completion
# 0                 Relax in this nice sienna armchair    furniture|chairs
# 1  This video camera is perfect for capturing tho...  electronics|camera
# 2  You get a whole bunch of stuff and it is super...     beauty|grooming
# 3                              A must-have for April     seasonal|easter
# 4                      Unsurpassed for every kitchen  housewares|kitchen

# %%
val_df.head(50)
# Out:
#                                                prompt              completion
# 0         Outstanding white worktable for your office        furniture|tables
# 1                          A favorite for early April         seasonal|easter
# 2                   Ideal white chair for your office        furniture|chairs
# 3   This acoustic drum will delight the most deman...  instruments|percussion
# 4   This keyboard will delight the most demanding ...        instruments|keys
# 5   An all-around modish pair of powder blue sneakers        footwear|sneaker
# 6   This jar candle is a must-have for the lightin...      homedecor|lighting
# 7             This ceramic vase will delight everyone    homedecor|decorative
# 8   This unparalleled dresser has lots of drawers ...      furniture|dressers
# 9                                Sassy belt for women        accessories|belt
# 10  This flavorful veggie is a must-have in every ...    groceries|vegetables
# 11                  Dapper dressy white shirt for men           apparel|shirt
# 12  This acoustic bass will delight the most deman...     instruments|strings
# 13       A foxy bracelet for women to adorn any wrist        jewelry|bracelet
# 14  This electric guitar will delight the most dem...     instruments|strings
# 15      Our beef is raised sustainably by our farmers          groceries|meat
# 16  This floor lamp is a must-have for the lightin...      homedecor|lighting
# 17  A great selection of makeup brushes; look good...         beauty|grooming
# 18                         A favorite for early April         seasonal|easter
# 19         Video camera for amateurs and professonals      electronics|camera
# 20  This delicious berry apple pie is made fresh e...        groceries|bakery
# 21  This rich yellow sofa will be the highlight of...         furniture|sofas
# 22  Roses arrangement grown sustainably on our org...      floral|arrangement
# 23          Take video anywhere, anytime, like a spy.      electronics|camera
# 24                       A must-have for the holidays      seasonal|christmas
# 25               This blue cushion set is very trendy       homedecor|cushion
# 26  This unparalleled dresser has one drawer to or...      furniture|dressers
# 27  This dark olive green backpack for women is ou...    accessories|backpack
# 28                      Unsurpassed for every kitchen      housewares|kitchen
# 29  This electric bass will delight the most deman...     instruments|strings
# 30  Outstanding dark slate gray worktable for your...        furniture|tables
# 31    Outstanding burlywood worktable for your office        furniture|tables
# 32  This grand piano is perfect for amateur and pr...        instruments|keys
# 33                       A must-have for your kitchen      housewares|kitchen
# 34          Unequaled black chair for any dining room        furniture|chairs
# 35  Roses arrangement grown sustainably on our org...      floral|arrangement
# 36                       Gainsboro backpack for women    accessories|backpack
# 37                             Voguish belt for women        accessories|belt
# 38           Cupcake made fresh daily in our kitchens        groceries|bakery
# 39        Be sure to order early for that special day      seasonal|valentine
# 40                   Unrivaled gray sofa for any room         furniture|sofas
# 41                            Ideal for every kitchen      housewares|kitchen
# 42                             Swanky dress for women           apparel|shirt
# 43  Swell pair of pale gray sneakers for gallivant...        footwear|sneaker
# 44             Relax in this comfy dark gray armchair        furniture|chairs
# 45                 Pair of brown formal shoes for men         footwear|formal
# 46            Outstanding fishing reel for every pole        outdoors|fishing
# 47                        Sans pareil scarf for women           apparel|scarf
# 48           This taper candle will enhance your home      homedecor|lighting
# 49                     Unparalleled for every kitchen      housewares|kitchen

# %% [markdown]
# # 4. JSONL 파일 생성

# %%
def create_json_file(df, jsonl_file_path):

    # Iterate over DataFrame rows and write each row as a JSON object to the file
    with open(jsonl_file_path, 'w') as jsonl_file:
        for index, row in df.iterrows():
            json_row = row.to_json()
            # print("json_row: ", json_row)
            jsonl_file.write(json_row)
            jsonl_file.write('\n')
    print(f"{jsonl_file_path} is created")

# %%
# Specify the path where you want to save the JSONL file
jsonl_file_path = 'train-retail-data-en.jsonl'
create_json_file(train_df, jsonl_file_path)


jsonl_file_path = 'val-retail-data-en.jsonl'
create_json_file(val_df, jsonl_file_path)
# Out:
# train-retail-data-en.jsonl is created
# val-retail-data-en.jsonl is created
